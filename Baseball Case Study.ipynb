# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Data Inspection

# %%
# checking the data shape 
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Above we have 30 rows and 17 columns in dataset.

# %%
# checking the data types
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# All the columns are Integer type except ERA it is a float type.

# %%
# Checking the null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Dataset has no missing value.

# %%
# describe about dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Univariate Analysis

# %%
# Wins
plt.figure(figsize=(8,5))
sn.countplot('W',data=df,palette='ocean')
# Out:
# <AxesSubplot:xlabel='W', ylabel='count'>

# %%
# Runs
plt.figure(figsize=(25,7))
sn.countplot('R',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='R', ylabel='count'>

# %%
# At Bats
plt.figure(figsize=(25,7))
sn.countplot('AB',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='AB', ylabel='count'>

# %%
# Hits
plt.figure(figsize=(25,7))
sn.countplot('H',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='H', ylabel='count'>

# %%
# Doubles
plt.figure(figsize=(25,7))
sn.countplot('2B',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='2B', ylabel='count'>

# %%
# Triples
plt.figure(figsize=(25,7))
sn.countplot('3B',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='3B', ylabel='count'>

# %%
# Hit Runs
plt.figure(figsize=(25,7))
sn.countplot('HR',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='HR', ylabel='count'>

# %%
# Earned Runs
plt.figure(figsize=(25,7))
sn.countplot('ER',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='ER', ylabel='count'>

# %%
df.hist(bins=10,figsize=(15,12))
plt.show()

# %% [markdown]
# Above plot shows the histogram of different columns.

# %%
sn.distplot(df["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sn.distplot(df["R"])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sn.distplot(df["AB"])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sn.distplot(df["H"])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sn.distplot(df["2B"])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sn.distplot(df["3B"])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sn.distplot(df["HR"])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sn.distplot(df["BB"])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sn.distplot(df["RA"])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sn.distplot(df["ER"])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sn.distplot(df["ERA"])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %% [markdown]
# Above distplot graph shows that the graph are Normally distributed and all other a little bit left skewed or right skewed.

# %% [markdown]
# # Bivariate Analysis

# %%
# Doubles to Wins
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='2B',data=df)
plt.xlabel('2B')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
# R to Wins
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='R',data=df)
plt.xlabel('R')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
# Triples to Wins
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='3B',data=df)
plt.xlabel('3B')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
# Runs Allowed to Wins
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='RA',data=df)
plt.xlabel('RA')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
# Hitruns to Wins
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='HR',data=df)
plt.xlabel('HR')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
# Earned Runs to Wins
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='ER',data=df)
plt.xlabel('ER')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
# Earned Run Average to Wins 
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='ERA',data=df)
plt.xlabel('ERA')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
# Complete Games to Wins
plt.figure(figsize=(8,5))
plt.scatter(y='W',x='CG',data=df)
plt.xlabel('CG')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %%
plt.figure(figsize=(10,6))
sn.scatterplot(x='RA',y='HR',data=df,hue='W')
# Out:
# <AxesSubplot:xlabel='RA', ylabel='HR'>

# %%
plt.figure(figsize=(10,6))
sn.scatterplot(x='2B',y='3B',data=df,hue='W')
# Out:
# <AxesSubplot:xlabel='2B', ylabel='3B'>

# %% [markdown]
# This plot shows the relation between doubles and triples to win the match.

# %% [markdown]
# It represent individual pieces of data using dots.these plots make it easier to see if two variables are related to each other.

# %% [markdown]
# # Multivariate Analysis

# %%
sn.pairplot(df)
plt.show()

# %% [markdown]
# # Identifying Outliers

# %%
columns=df.columns
columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df["W"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["R"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["AB"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["H"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["2B"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["3B"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["HR"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["BB"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SO"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SB"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["RA"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["ER"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["ERA"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["CG"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SHO"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SV"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["E"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in R , ERA, SHO, E

# %% [markdown]
# # Correlation matrix

# %%
plt.figure(figsize=(15,10))
sn.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# In this dataset we don't use the Encoder because all the columns are in numerical.

# %% [markdown]
# # Outliers Removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
new_df=df [(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (29, 17)

# %%
df.shape
# Out:
# (30, 17)

# %%
(1/30)
# Out:
# 0.03333333333333333

# %% [markdown]
# # Find the Best Model

# %%
x = df.drop(['W'] , axis=1)
y = df['W']

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=7)

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
models = [SVR(),DecisionTreeRegressor(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor(),LinearRegression()]
for m in models:
    print(m)
    print('Cross Validation Score:',np.mean(cross_val_score(m,x_train,y_train,scoring='neg_mean_squared_error',cv=10)))
# Out:
# SVR()
# Cross Validation Score: -98.67830746763848
# DecisionTreeRegressor()
# Cross Validation Score: -120.98333333333332
# RandomForestRegressor()
# Cross Validation Score: -61.04351333333335
# AdaBoostRegressor()
# Cross Validation Score: -49.20168645483907
# GradientBoostingRegressor()
# Cross Validation Score: -86.29706956735431
# LinearRegression()
# Cross Validation Score: -340.4924779898284

# %%
models=[SVR(),DecisionTreeRegressor(),LinearRegression(),AdaBoostRegressor(),
        RandomForestRegressor()]

# %%
r2list=[]
def create_model(model):
    m=model
    m.fit(x_train,y_train)
    p=m.predict(x_test)
    

    r2=r2_score(y_test,p)
    r2list.append(r2)
    print(m)
    print('R2 Score',r2)
    print('----------------------------')

# %%
for i in models:
    create_model(i)
# Out:
# SVR()
# R2 Score 0.14354645557778223
# ----------------------------
# DecisionTreeRegressor()
# R2 Score 0.17604404458171075
# ----------------------------
# LinearRegression()
# R2 Score 0.4266108889812691
# ----------------------------
# AdaBoostRegressor()
# R2 Score 0.6935939139990628
# ----------------------------
# RandomForestRegressor()
# R2 Score 0.6250248422183429
# ----------------------------

# %% [markdown]
# # Hyper parameter Tuning

# %% [markdown]
# 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
# linearRegression
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.4266108889812691

# %% [markdown]
# 2. Lasso

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls = Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss = r2_score(y_test,pred_ls)
lss
# Out:
# 0.6107099821626327

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.018893646697027755

# %% [markdown]
# 3. Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf= RandomForestRegressor(criterion="mae",max_features="auto")
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_decision = rf.predict(x_test)

rfs = r2_score(y_test,pred_decision)
print('R2 Score:' ,rfs*100)

rfscore = cross_val_score(rf,x,y,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:' ,rfc*100)
# Out:
# R2 Score: 57.800596213240226
# Cross Val Score: -79.35083903910505

# %% [markdown]
# 4. Ridge Regressor

# %%
from sklearn.linear_model import Ridge

# %%
from sklearn.model_selection  import cross_val_score as CVS
from sklearn import metrics

# %%
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score as R2

# %%
regressor_rd = Ridge(normalize=True)

# %%
regressor_rd.fit(x_train,y_train)
# Out:
# Ridge(normalize=True)

# %%
RD_MAE = round(MAE(y_test, y_pred),2)
RD_MSE = round(MSE(y_test, y_pred),2)
RD_R_2 = round(R2(y_test, y_pred),4)
RD_CS  = round(CVS(regressor_rd, x, y, cv=5).mean(),4)

print(f" Mean Absolute Error: {RD_MAE}\n")
print(f" Mean Squared Error: {RD_MSE}\n")
print(f" R2 Score: {RD_R_2}\n")
# Out:
#  Mean Absolute Error: 4.89
#
#  Mean Squared Error: 34.19
#
#  R2 Score: 0.7062

# %% [raw]
# Models                         r2_score
# 1.Linear Regression            0.42
# 2.Random Forest Regressor      0.62
# 3.Lasso                        0.61
# 4.Ridge Regressor              0.70

# %% [markdown]
# Ridge Regressor is the best model because its r2_score is 0.70

# %% [markdown]
# # Saving the model

# %%
import pickle
filename = 'Baseball.pkl'
pickle.dump(regressor_rd, open(filename, 'wb'))
