# %%
import pandas as pd

# %%
df=pd.read_csv("avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# Dataframe have 18249 rows and 14 columns

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# There are 3 columns with object type data rest all the columns have integer type values and float type values.

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %% [markdown]
# The first column is index so we drop it to get clean data.

# %% [markdown]
# # Missing Data

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# There are no null values in the dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
# type
plt.figure(figsize=(10,3))
sn.countplot(df['type'])
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# Above plot shows the type of avocado.

# %%
# Bar Chart to indicate the year
plt.figure(figsize=[10,5])
sn.countplot(x = 'year', data =df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
# Average Price
plt.figure(figsize=(10,3))
sn.countplot(df['AveragePrice'])
df['AveragePrice'].value_counts()
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 2.91      1
# 2.68      1
# 3.04      1
# 3.17      1
# 3.03      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
sn.distplot(df["AveragePrice"])
print('Maximum',df['AveragePrice'].max())
print('Minimum',df['AveragePrice'].min())
# Out:
# Maximum 3.25
# Minimum 0.44

# %% [markdown]
# It appears that the data distribution in the average price ranges between 0.3 & 3.4 The upper values of the distribution are at  Most of the data is concentrated between 0.9 to 1.8.

# %%
#average price by avocado type
sn.boxplot(x='type',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
#Price by year
sn.boxplot(x='year',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
plt.figure(figsize =(11,6))
plt.title('Avocado price in each country')
plt.xticks(rotation ='vertical')
sn.boxplot(x = 'region', y = 'AveragePrice', data = df, width = 1, whis= 2)
# Out:
# <AxesSubplot:title={'center':'Avocado price in each country'}, xlabel='region', ylabel='AveragePrice'>

# %% [markdown]
# Regarding the prices relative to the regions, we find that San Francisco is the most expensive city to sell avocados in general, Houston is the cheapest area to sell.

# %%
# Average price to total volume
plt.scatter(x='Total Volume',y='AveragePrice',data=df)

# %%
sn.scatterplot(x='Large Bags', y='AveragePrice', data=df, hue='type')
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='AveragePrice'>

# %%
sn.scatterplot(x='Small Bags', y='AveragePrice', data=df, hue='type')
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='AveragePrice'>

# %%
df.hist(bins=10,figsize=(15,12))
plt.show()

# %% [markdown]
# Revenue generate in each year

# %%
#Revenue each year
df['revenue_daily'] = df['AveragePrice']*df['Total Volume']
df['revenue_plu4046'] = df['AveragePrice']*df['4046']
df['revenue_plu4225'] = df['AveragePrice']*df['4225']
df['revenue_plu4770'] = df['AveragePrice']*df['4770']

# %%
#Total Revenue each year
sn.barplot(x='year', y='revenue_daily', estimator = sum, data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='revenue_daily'>

# %% [markdown]
# According to above graph in 2017 revenue of avocado is more.

# %%
#Revenue by type and year
sn.barplot(x='year', y='revenue_daily', hue='type',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='revenue_daily'>

# %%
#Plotting the Organic and Conventional Avacado price

# %%
plt.figure(figsize=(14,5))
sn.scatterplot(data=df["AveragePrice"],label="Organic")
plt.xlabel("Date")
plt.title('Avocado prices')
# Out:
# Text(0.5, 1.0, 'Avocado prices')

# %%
plt.figure(figsize=(14,5))
sn.scatterplot(data=df["AveragePrice"],label="Conventional")
plt.xlabel("Date")
plt.title('Avocado prices')
# Out:
# Text(0.5, 1.0, 'Avocado prices')

# %%
#Plotting Volume

# %%
plt.figure(figsize=(14,5))
sn.scatterplot(data=df["Total Volume"],label="Organic")
plt.xlabel("Date")
plt.title(' Volume Avocado sold')
# Out:
# Text(0.5, 1.0, ' Volume Avocado sold')

# %%
plt.figure(figsize=(10,3))
sn.scatterplot(data=df["Total Volume"],label="Conventional")
plt.xlabel("Date")
plt.title(' Volume Avocado sold')
# Out:
# Text(0.5, 1.0, ' Volume Avocado sold')

# %% [markdown]
# AVOCADO VOLUME TRENDS

# %% [markdown]
# 1.Yearly trends for Total Sales and Sales with PLU types.
# 2.Monthly Trends for Total Sales and Sales with PLU types.
# 3.Relation between AveragePrice and Total Sales

# %%
# datasets for each year.
df_2015 = df.loc[df.year==2015]
df_2016 = df.loc[df.year==2016]
df_2017 = df.loc[df.year==2017]
df_2018 = df.loc[df.year==2018]

# %%
sn.scatterplot( x='AveragePrice', y='Total Volume', data=df_2015, hue='type')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
sn.scatterplot( x='AveragePrice', y='Total Volume', data=df_2016, hue='type')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
sn.scatterplot( x='AveragePrice', y='Total Volume', data=df_2017, hue='type')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
sn.scatterplot( x='AveragePrice', y='Total Volume', data=df_2018, hue='type')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %% [markdown]
# Customers tends to buy more when price of avocado is less than 1.5 per unit. But this is for conventional type Avocado. For Organic type, there is same sale rate irrespective of its price in each year.

# %% [markdown]
# # Checking for Coorelation

# %%
plt.figure(figsize=(15,10))
sn.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Importing Label Encoder

# %%
columns=df.columns
columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'revenue_daily', 'revenue_plu4046', 'revenue_plu4225',
#        'revenue_plu4770'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df = df.apply(LabelEncoder().fit_transform)

# %% [markdown]
# # Finding the Best Model

# %%
X = df.drop('AveragePrice', axis=1)
y = df['AveragePrice']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
np.random.seed(42)

reg = RandomForestRegressor(n_estimators=100)
reg.fit(X_train, y_train)

y_preds = reg.predict(X_test)
y_preds

reg.score(X_test, y_test)
# Out:
# 0.9461450946609589

# %%
#Gradeint boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor
np.random.seed(42)

reg = GradientBoostingRegressor()
reg.fit(X_train, y_train)

y_preds = reg.predict(X_test)
y_preds

reg.score(X_test, y_test)
# Out:
# 0.8188263255502828

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
np.random.seed(42)

reg = DecisionTreeRegressor()
reg.fit(X_train, y_train)

y_preds = reg.predict(X_test)
y_preds

reg.score(X_test, y_test)
# Out:
# 0.8741941310787762

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
np.random.seed(42)

reg = LinearRegression()
reg.fit(X_train, y_train)

y_preds = reg.predict(X_test)
y_preds

reg.score(X_test, y_test)
# Out:
# 0.9065394065194392

# %%
# Ada Boost Regressor
from sklearn.ensemble import AdaBoostRegressor
np.random.seed(42)

rg = AdaBoostRegressor()
rg.fit(X_train, y_train)

y_preds = rg.predict(X_test)
y_preds

rg.score(X_test, y_test)
# Out:
# 0.6486436307185411

# %%
from sklearn.metrics import r2_score

# %%
models=[DecisionTreeRegressor(),LinearRegression(),AdaBoostRegressor(),
        RandomForestRegressor(),GradientBoostingRegressor()]

# %%
r2list=[]
def create_model(model):
    m=model
    m.fit(X_train,y_train)
    p=m.predict(X_test)
    

    r2=r2_score(y_test,p)
    r2list.append(r2)
    print(m)
    print('R2 Score',r2)
    print('----------------------------')

# %%
for i in models:
    create_model(i)
# Out:
# DecisionTreeRegressor()
# R2 Score 0.8737857054639726
# ----------------------------
# LinearRegression()
# R2 Score 0.9065394065194392
# ----------------------------
# AdaBoostRegressor()
# R2 Score 0.6337291214241283
# ----------------------------
# RandomForestRegressor()
# R2 Score 0.9461596449817575
# ----------------------------
# GradientBoostingRegressor()
# R2 Score 0.8188638520900691
# ----------------------------

# %% [markdown]
# # Hyper parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Lasso Regressor
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha=0.001,random_state=0)
ls.fit(X_train,y_train)
ls.score(X_train,y_train)
pred_ls = ls.predict(X_test)

lss = r2_score(y_test,pred_ls)
lss
# Out:
# 0.8914638882583125

# %%
# RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = [
    {'n_estimators':[3,10,30],'max_features':[2,4,6,8]},
    {'bootstrap':[False],'n_estimators':[3,10],
    'max_features':[2,3,4]}
]
reg = RandomForestRegressor(random_state=44)
grid_search_cv = GridSearchCV(estimator=reg,param_grid=param_grid,cv=5,scoring='neg_mean_squared_error',return_train_score=True)
grid_search_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=44),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search_cv.best_params_,grid_search_cv.best_estimator_
# Out:
# ({'max_features': 8, 'n_estimators': 30},
#  RandomForestRegressor(max_features=8, n_estimators=30, random_state=44))

# %%
rnd_reg=grid_search_cv.best_estimator_

# %%
y_pred = rnd_reg.predict(X_test)
final_mse = mean_squared_error(y_test,y_pred)
print(np.sqrt(final_mse))
# Out:
# 9.571049685652872

# %%
# Ridge Regressor
from sklearn.linear_model import Ridge

# %%
from sklearn.model_selection  import cross_val_score as CVS
from sklearn import metrics

# %%
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score as R2

# %%
regressor_rd = Ridge(normalize=True)

# %%
regressor_rd.fit(X_train,y_train)
# Out:
# Ridge(normalize=True)

# %%
RD_MAE = round(MAE(y_test, y_pred),2)
RD_MSE = round(MSE(y_test, y_pred),2)
RD_R_2 = round(R2(y_test, y_pred),4)
RD_CS  = round(CVS(regressor_rd, X, y, cv=5).mean(),4)

print(f" Mean Absolute Error: {RD_MAE}\n")
print(f" Mean Squared Error: {RD_MSE}\n")
print(f" R2 Score: {RD_R_2}\n")
# Out:
#  Mean Absolute Error: 19.04
#
#  Mean Squared Error: 562.59
#
#  R2 Score: 0.6486

# %% [markdown]
# Models                         r2_score
# 1.Linear Regression            0.90
# 2.Random Forest Regressor      0.94
# 3.Lasso                        0.89
# 4.Ridge Regressor              0.64
# 5.Decision Tree Regressor      0.87
# 6.Ada Boost Regressor          0.63
# 7.GradientBoostRegressor       0.81

# %% [markdown]
# From the above model, Random Forest Regressor are the best Model beacause its r_2 score is 0.94.

# %% [markdown]
# # Saving the model

# %%
import pickle
filename = 'Avocado.pkl'
pickle.dump(reg, open(filename, 'wb'))
