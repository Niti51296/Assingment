# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv")
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %% [markdown]
# We have 8124 rows and 23 columns in dataset

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# All dataset is object type

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# Our dataset has no missing value

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %% [markdown]
# Two types of mushroom poisonous and edible

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
labels = 'Mushroom-Edible', 'Mushroom-Poisonous'

fig, ax = plt.subplots()
ax.pie(df['class'].value_counts(),labels=labels, autopct='%1.2f%%', shadow=True)

plt.show()

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %% [markdown]
# Count of each value is 8124, therefore no missing values.

# %% [markdown]
# # Univariate Analysis

# %%
sn.countplot(df['class']);

# %% [markdown]
# Edible Mushroom are more than the Poisonous Mushroom

# %%
sn.countplot(x ='cap-shape', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='cap-shape', ylabel='count'>

# %%
sn.countplot(x ='cap-surface', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='cap-surface', ylabel='count'>

# %%
sn.countplot(x ='cap-color', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='cap-color', ylabel='count'>

# %%
sn.countplot(x ='bruises', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='bruises', ylabel='count'>

# %%
sn.countplot(x ='odor', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='odor', ylabel='count'>

# %%
sn.countplot(x ='gill-attachment', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='gill-attachment', ylabel='count'>

# %%
sn.countplot(x ='gill-spacing', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='gill-spacing', ylabel='count'>

# %%
sn.countplot(x ='gill-size', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='gill-size', ylabel='count'>

# %%
sn.countplot(x ='gill-color', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='gill-color', ylabel='count'>

# %%
sn.countplot(x ='stalk-surface-below-ring', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='stalk-surface-below-ring', ylabel='count'>

# %%
sn.countplot(x ='stalk-color-above-ring', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='stalk-color-above-ring', ylabel='count'>

# %%
sn.countplot(x ='stalk-color-below-ring', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='stalk-color-below-ring', ylabel='count'>

# %%
sn.countplot(x ='veil-type', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='veil-type', ylabel='count'>

# %%
sn.countplot(x ='veil-color', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='veil-color', ylabel='count'>

# %%
sn.countplot(x ='ring-number', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='ring-number', ylabel='count'>

# %%
sn.countplot(x ='ring-type', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='ring-type', ylabel='count'>

# %%
sn.countplot(x ='spore-print-color', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='spore-print-color', ylabel='count'>

# %%
sn.countplot(x ='population', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='population', ylabel='count'>

# %%
sn.countplot(x ='habitat', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='habitat', ylabel='count'>

# %% [markdown]
# Countplot of all the columns.

# %% [markdown]
# # Converting All the columns to numeric using Label Encoder as all the columns content categorical data

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df = df.apply(LabelEncoder().fit_transform)

# %% [markdown]
# # Checking for Coorelation

# %%
plt.figure(figsize=(15,10))
sn.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df["class"].unique
# Out:
# <bound method Series.unique of 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32>

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# # Model Selection

# %%
x = df.drop(['class'] , axis=1)
y = df['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=0)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state = 0 , max_depth = 5)
dt.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=0)

# %%
dt.score(x_train , y_train)
# Out:
# 0.9778403095321843

# %%
predictions = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , predictions)
# Out:
# 0.9827727645611156

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth = 5)

# %%
rf.fit(x_train , y_train)
rf.score(x_train , y_train)
# Out:
# 0.9899753781217024

# %%
predictions = rf.predict(x_test)
rf.score(x_test ,y_test)
# Out:
# 0.9905660377358491

# %%
accuracy_score(y_test , predictions)
# Out:
# 0.9905660377358491

# %% [markdown]
#  1.DECISION TREE ACCURACY-98.2%
#
#  2.RANDOM FOREST ACCURACY-99%
#
#  HENCE,RANDOM FOREST IS COMPARITIVELY BETTER.
